# %%
student_name = str("Jude")
age = int(25)
height = float(5.36)
student_class=str("2B")
print(student_class)
# Out:
# 2B

# %%
mark1, mark2, mark3 = 90, 23, 45
marks1= marks2= marks3=90
print(marks2)
# Out:
# 90

# %%
def print_message():
    message = "Hello My Friends"
    print(message)

print_message()
# Out:
# Hello My Friends

# %%
print_message()
# Out:
# Hello My Friends

# %%
def quad_calulator(a, b, c):
    discriminant = (b**2)-(4*a*c)
    print(student_name)
    print(discriminant)
    x1= (-b+(discriminant**(1/2)))/(2*a)
    x2= (-b-(discriminant**(1/2)))/(2*a)
    print(x1)
    print(x2)

# %%
quad_calulator(-10, -3, 1)
# Out:
# Jude
# 49
# -0.5
# 0.2

# %%
input1=input("Please input your year of birth")
input2=input("Please input corrent year")
#Convert inputs to number
year_of_birth=int(input1)
current_year=int(input2)
#Calculate age:
age= current_year-year_of_birth
#Convert Age to string
age_text=str(age)
print(f"You are {age_text} years old")
# Out:
# Please input your year of birth 1993
# Please input corrent year 2025
# You are 32 years old
