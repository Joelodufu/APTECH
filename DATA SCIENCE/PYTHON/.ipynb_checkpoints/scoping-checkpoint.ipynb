# %%
name = "Samuel"
age=45
height=6.5

def sayProfile():
    name="John"
    age=50
    height=5.6
    print(name, "is", age, "Years Old, and he is", height, "feet tall")

# %%
print(age)
sayProfile()
# Out:
# 45
# John is 50 Years Old, and he is 5.6 feet tall
