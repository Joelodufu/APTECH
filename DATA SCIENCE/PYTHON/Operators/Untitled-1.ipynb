# %%
#Integers
x=5
y=7
z=0

print(x-y+z) #Addition
# Out:
# -2

# %%
is_logged_in = False
is_admin = False

if is_logged_in:
    print("He is Logged In")

# %%
name = 'John'   
id = '1234'
identity = 1234
deathYear= None

# %%
#REFERENCE DATA / NON-PRIMITIVE
#LISTS
Fruits = ['Apple', 'Banana', 'Orange']
Fruits.append("Guava")
Fruits.remove("Banana")
Fruits[2]="Mango"
print(Fruits)

#TUPLES
Coordinates = (10.0, 20.0)
print(Coordinates[0])

#SETS
UniqueNumbers = {1, 2, 3, 4, 5}
print(UniqueNumbers)
# Out:
# ['Apple', 'Orange', 'Mango']
# 10.0
# {1, 2, 3, 4, 5}

# %%
a=10
b=11
result = a**b
print(result)
# Out:
# 100000000000

# %%
message = "I am a good person, i dont like trouble"
result = "trouble" in message
print(result)
# Out:
# True

# %%
post= "Hello this is a post made by random person who  Nigerian fucker"
foulFlag1= "hate"
foulFlag2= "fuck"
foulFlag3= "mad "
if (foulFlag1 in post or foulFlag2 in post or foulFlag3 in post):
    print("Your post contain Foul Words, please rewrite...")
else:
    print(post)
# Out:
# Your post contain Foul Words, please rewrite...
