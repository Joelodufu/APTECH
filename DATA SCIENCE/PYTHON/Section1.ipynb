# %%
print("Hello World")
# Out:
# Hello World

# %%
name ="Samson"
age = 20
height = 5.9
is_student = True

print("My name is "+ name+" and I am "+ str(age) + " years old."+ " My height is " + str(height) + " feet." + " Am I a student? " + str(is_student))
# Out:
# My name is Samson and I am 20 years old. My height is 5.9 feet. Am I a student? True
